# %% [markdown]
# ## Program that searches for Bars nearby

# %% [markdown]
# starting coordinates: Home - Romero y Cordero 209

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


import folium # plotting library

print('Folium imported')
print('Libraries imported.')
# Out:
# Folium imported
# Libraries imported.

# %%
CLIENT_ID = '2BOJBTIFPAIFAECFCKJT4H5W404CWPNYYY0SVHFFOFKPWNZV' # your Foursquare ID
CLIENT_SECRET = '5VNGWKFYYVIEHTGME0IBVR5AQ5LCP5WPBVLSSQFUMOZMSFKM' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 2BOJBTIFPAIFAECFCKJT4H5W404CWPNYYY0SVHFFOFKPWNZV
# CLIENT_SECRET:5VNGWKFYYVIEHTGME0IBVR5AQ5LCP5WPBVLSSQFUMOZMSFKM

# %%
lati=-0.141189
longi=-78.479422
search_query = 'bar' #what type of restaurant for example
radius = 500 #search radius from initial location
print(search_query + ' .... OK!')
# Out:
# bar .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lati, longi, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2BOJBTIFPAIFAECFCKJT4H5W404CWPNYYY0SVHFFOFKPWNZV&client_secret=5VNGWKFYYVIEHTGME0IBVR5AQ5LCP5WPBVLSSQFUMOZMSFKM&ll=-0.141189,-78.479422&v=20180604&query=bar&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d24de73531593002c5bf6e1'},
#  'response': {'venues': [{'id': '54278b33498eabdbcf92e540',
#     'name': "lucy's Nectar's BAR",
#     'location': {'lat': -0.13978970050811768,
#      'lng': -78.47955322265625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -0.13978970050811768,
#        'lng': -78.47955322265625}],
#      'distance': 156,
#      'cc': 'EC',
#      'country': 'Ecuador',
#      'formattedAddress': ['Ecuador']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562697331',
#     'hasPerk': False},
#    {'id': '4f1c674ee4b095bc46b97d88',
#     'name': 'La Barca del Marisco',
#     'location': {'address': 'capitán Ramón Borja',
#      'lat': -0.1406746419238304,
#      'lng': -78.47951778473663,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -0.1406746419238304,
#        'lng': -78.47951778473663}],
#      'distance': 58,
#      'cc': 'EC',
#      'city': 'Quito',
#      'state': 'Pichincha',
#      'country': 'Ecuador',
#      'formattedAddress': ['capitán Ramón Borja', 'Quito', 'Ecuador']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562697331',
#     'hasPerk': False},
#    {'id': '514d2d1ae4b073c933ca6fac',
#     'name': 'lozada drinking bar',
#     'location': {'lat': -0.14335380494594574,
#      'lng': -78.48233795166016,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -0.14335380494594574,
#        'lng': -78.48233795166016}],
#      'distance': 404,
#      'cc': 'EC',
#      'city': 'Quito',
#      'state': 'Pichincha',
#      'country': 'Ecuador',
#      'formattedAddress': ['Quito', 'Ecuador']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562697331',
#     'hasPerk': False},
#    {'id': '54272152498e4036e2dcb1e3',
#     'name': 'La Barca de Mariscos',
#     'location': {'address': 'Cap. Ramón Borja',
#      'lat': -0.140501,
#      'lng': -78.478822,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -0.140501,
#        'lng': -78.478822}],
#      'distance': 101,
#      'cc': 'EC',
#      'city': 'Quito',
#      'state': 'Pichincha',
#      'country': 'Ecuador',
#      'formattedAddress': ['Cap. Ramón Borja', 'Kennedy', 'Ecuador']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562697331',
#     'hasPerk': False},
#    {'id': '53335503498ebd7a99d82843',
#     'name': 'Barbacoas U-YEAH',
#     'location': {'address': 'Gonzalo Zaldumbide',
#      'crossStreet': 'Rafael Bustamante',
#      'lat': -0.14323939383029938,
#      'lng': -78.47785949707031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -0.14323939383029938,
#        'lng': -78.47785949707031}],
#      'distance': 286,
#      'cc': 'EC',
#      'city': 'Kennedy',
#      'state': 'Pichincha',
#      'country': 'Ecuador',
#      'formattedAddress': ['Gonzalo Zaldumbide (Rafael Bustamante)',
#       'Kennedy',
#       'Ecuador']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562697331',
#     'hasPerk': False},
#    {'id': '511a6ab7759629b5061897ff',
#     'name': 'Alvarez Barba S.A.',
#     'location': {'address': 'AV. 10 de Agosto N51-97 Frente a la',
#      'crossStreet': 'Algarrobos',
#      'lat': -0.14378537318276124,
#      'lng': -78.48362002532822,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -0.14378537318276124,
#        'lng': -78.48362002532822}],
#      'distance': 549,
#      'cc': 'EC',
#      'city': 'Quito',
#      'state': 'Pichincha',
#      'country': 'Ecuador',
#      'formattedAddress': ['AV. 10 de Agosto N51-97 Frente a la (Algarrobos)',
#       'Quito',
#       'Ecuador']},
#     'categories': [{'id': '4eb1c1623b7b52c0e1adc2ec',
#       'name': 'Auto Dealership',
#       'pluralName': 'Auto Dealerships',
#       'shortName': 'Auto Dealer',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562697331',
#     'hasPerk': False},
#    {'id': '52c8ab1811d2663271575654',
#     'name': 'la kennedy barrio fino',
#     'location': {'lat': -0.13860701015854754,
#      'lng': -78.47998677024268,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -0.13860701015854754,
#        'lng': -78.47998677024268}],
#      'distance': 294,
#      'cc': 'EC',
#      'state': 'Pichincha',
#      'country': 'Ecuador',
#      'formattedAddress': ['Ecuador']},
#     'categories': [{'id': '50aa9e094b90af0d42d5de0d',
#       'name': 'City',
#       'pluralName': 'Cities',
#       'shortName': 'City',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562697331',
#     'hasPerk': False},
#    {'id': '50cbcdede4b0d4bd0fd6723a',
#     'name': 'Liga Barrial El Inca cancha El Morlan',
#     'location': {'lat': -0.14347769863880666,
#      'lng': -78.47614627212396,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -0.14347769863880666,
#        'lng': -78.47614627212396}],
#      'distance': 444,
#      'cc': 'EC',
#      'city': 'Quito',
#      'state': 'Pichincha',
#      'country': 'Ecuador',
#      'formattedAddress': ['Quito', 'Ecuador']},
#     'categories': [{'id': '4cce455aebf7b749d5e191f5',
#       'name': 'Soccer Field',
#       'pluralName': 'Soccer Fields',
#       'shortName': 'Soccer Field',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_soccer_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562697331',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 1  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 3  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...    False
# 4  [{'id': '4bf58dd8d48988d1df931735', 'name': 'B...    False
#
#                          id     location.address location.cc location.city  \
# 0  54278b33498eabdbcf92e540                  NaN          EC           NaN
# 1  4f1c674ee4b095bc46b97d88  capitán Ramón Borja          EC         Quito
# 2  514d2d1ae4b073c933ca6fac                  NaN          EC         Quito
# 3  54272152498e4036e2dcb1e3     Cap. Ramón Borja          EC         Quito
# 4  53335503498ebd7a99d82843   Gonzalo Zaldumbide          EC       Kennedy
#
#   location.country location.crossStreet  location.distance  \
# 0          Ecuador                  NaN                156
# 1          Ecuador                  NaN                 58
# 2          Ecuador                  NaN                404
# 3          Ecuador                  NaN                101
# 4          Ecuador    Rafael Bustamante                286
#
#                            location.formattedAddress  \
# 0                                          [Ecuador]
# 1              [capitán Ramón Borja, Quito, Ecuador]
# 2                                   [Quito, Ecuador]
# 3               [Cap. Ramón Borja, Kennedy, Ecuador]
# 4  [Gonzalo Zaldumbide (Rafael Bustamante), Kenne...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': -0.13978970050811...     -0.139790
# 1  [{'label': 'display', 'lat': -0.14067464192383...     -0.140675
# 2  [{'label': 'display', 'lat': -0.14335380494594...     -0.143354
# 3  [{'label': 'display', 'lat': -0.140501, 'lng':...     -0.140501
# 4  [{'label': 'display', 'lat': -0.14323939383029...     -0.143239
#
#    location.lng location.state                  name    referralId
# 0    -78.479553            NaN   lucy's Nectar's BAR  v-1562697331
# 1    -78.479518      Pichincha  La Barca del Marisco  v-1562697331
# 2    -78.482338      Pichincha   lozada drinking bar  v-1562697331
# 3    -78.478822      Pichincha  La Barca de Mariscos  v-1562697331
# 4    -78.477859      Pichincha      Barbacoas U-YEAH  v-1562697331

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                     name  \
# 0                    lucy's Nectar's BAR
# 1                   La Barca del Marisco
# 2                    lozada drinking bar
# 3                   La Barca de Mariscos
# 4                       Barbacoas U-YEAH
# 5                     Alvarez Barba S.A.
# 6                 la kennedy barrio fino
# 7  Liga Barrial El Inca cancha El Morlan
#
#                                  categories  \
# 0  Residential Building (Apartment / Condo)
# 1                        Seafood Restaurant
# 2                                       Bar
# 3                        Seafood Restaurant
# 4                                 BBQ Joint
# 5                           Auto Dealership
# 6                                      City
# 7                              Soccer Field
#
#                                address  cc     city  country  \
# 0                                  NaN  EC      NaN  Ecuador
# 1                  capitán Ramón Borja  EC    Quito  Ecuador
# 2                                  NaN  EC    Quito  Ecuador
# 3                     Cap. Ramón Borja  EC    Quito  Ecuador
# 4                   Gonzalo Zaldumbide  EC  Kennedy  Ecuador
# 5  AV. 10 de Agosto N51-97 Frente a la  EC    Quito  Ecuador
# 6                                  NaN  EC      NaN  Ecuador
# 7                                  NaN  EC    Quito  Ecuador
#
#          crossStreet  distance  \
# 0                NaN       156
# 1                NaN        58
# 2                NaN       404
# 3                NaN       101
# 4  Rafael Bustamante       286
# 5         Algarrobos       549
# 6                NaN       294
# 7                NaN       444
#
#                                     formattedAddress  \
# 0                                          [Ecuador]
# 1              [capitán Ramón Borja, Quito, Ecuador]
# 2                                   [Quito, Ecuador]
# 3               [Cap. Ramón Borja, Kennedy, Ecuador]
# 4  [Gonzalo Zaldumbide (Rafael Bustamante), Kenne...
# 5  [AV. 10 de Agosto N51-97 Frente a la (Algarrob...
# 6                                          [Ecuador]
# 7                                   [Quito, Ecuador]
#
#                                       labeledLatLngs       lat        lng  \
# 0  [{'label': 'display', 'lat': -0.13978970050811... -0.139790 -78.479553
# 1  [{'label': 'display', 'lat': -0.14067464192383... -0.140675 -78.479518
# 2  [{'label': 'display', 'lat': -0.14335380494594... -0.143354 -78.482338
# 3  [{'label': 'display', 'lat': -0.140501, 'lng':... -0.140501 -78.478822
# 4  [{'label': 'display', 'lat': -0.14323939383029... -0.143239 -78.477859
# 5  [{'label': 'display', 'lat': -0.14378537318276... -0.143785 -78.483620
# 6  [{'label': 'display', 'lat': -0.13860701015854... -0.138607 -78.479987
# 7  [{'label': 'display', 'lat': -0.14347769863880... -0.143478 -78.476146
#
#        state                        id
# 0        NaN  54278b33498eabdbcf92e540
# 1  Pichincha  4f1c674ee4b095bc46b97d88
# 2  Pichincha  514d2d1ae4b073c933ca6fac
# 3  Pichincha  54272152498e4036e2dcb1e3
# 4  Pichincha  53335503498ebd7a99d82843
# 5  Pichincha  511a6ab7759629b5061897ff
# 6  Pichincha  52c8ab1811d2663271575654
# 7  Pichincha  50cbcdede4b0d4bd0fd6723a

# %%
#dataframe_filtered.name #to visualize the venues nearby
dataframe_filtered = dataframe_filtered[(dataframe_filtered.categories == 'Bar')]#|(dataframe_filtered.categories == 'Seafood Restaurant')]
dataframe_filtered.head()
# Out:
#                   name categories address  cc   city  country crossStreet  \
# 2  lozada drinking bar        Bar     NaN  EC  Quito  Ecuador         NaN
#
#    distance  formattedAddress  \
# 2       404  [Quito, Ecuador]
#
#                                       labeledLatLngs       lat        lng  \
# 2  [{'label': 'display', 'lat': -0.14335380494594... -0.143354 -78.482338
#
#        state                        id
# 2  Pichincha  514d2d1ae4b073c933ca6fac

# %%
venues_map = folium.Map(location=[lati, longi], zoom_start=15) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the starting point (Home)
folium.CircleMarker(
    [lati, longi],
    radius=10,
    color='red',
    popup='You Are Here!',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
